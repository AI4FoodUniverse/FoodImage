# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from shutil import copyfile

csv_file = 'label.csv'  
data = pd.read_csv(csv_file)

image_folder = 'dataset'

train_folder = 'train'
val_folder = 'val'
test_folder = 'test'
for folder in [train_folder, val_folder, test_folder]:
    os.makedirs(folder, exist_ok=True)

train_data, test_data = train_test_split(data, test_size=0.2, shuffle=True, stratify=data['Firmness'], random_state=42)
val_data, test_data = train_test_split(test_data, test_size=0.5, shuffle=True, stratify=test_data['Firmness'], random_state=42)


def copy_images(data, dest_folder):
    for index, row in data.iterrows():
        image_name = row['Image_name'] + ".jpg"  
        source_path = os.path.join(image_folder, image_name)
        dest_path = os.path.join(dest_folder, image_name)
        copyfile(source_path, dest_path)

copy_images(train_data, train_folder)
copy_images(val_data, val_folder)
copy_images(test_data, test_folder)

# %% [markdown]
# ### the following is spilting dataset with augmentation

# %% [markdown]
# rt batch2

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from shutil import copyfile
import cv2
import numpy as np

csv_file = 'label/batch1+2label.csv'
data = pd.read_csv(csv_file)

image_folder = 'dataset_white/batch1+2_white'

train_folder = 'dataset_white/batch1+2_train'
val_folder = 'dataset_white/batch1+2_val'
test_folder = 'dataset_white/batch1+2_test'
for folder in [train_folder, val_folder, test_folder]:
    os.makedirs(folder, exist_ok=True)

train_data, test_data = train_test_split(data, test_size=0.2, shuffle=True, stratify=data['Firmness'], random_state=42)
val_data, test_data = train_test_split(test_data, test_size=0.5, shuffle=True, stratify=test_data['Firmness'], random_state=42)

def augment_image(image):
    # Image translation
    tx = np.random.randint(-20, 20)  # Random translation distance
    ty = np.random.randint(-20, 20)
    M_translate = np.float32([[1, 0, tx], [0, 1, ty]])  # Translation matrix
    translated_image = cv2.warpAffine(image, M_translate, (image.shape[1], image.shape[0]))

    # Image rotation
    angle = np.random.randint(-30, 30)  # Random rotation angle
    center = (image.shape[1] // 2, image.shape[0] // 2)  # Rotation center
    M_rotate = cv2.getRotationMatrix2D(center, angle, 1.0)  # Rotation matrix
    rotated_image = cv2.warpAffine(translated_image, M_rotate, (image.shape[1], image.shape[0]))
    
    return rotated_image

def copy_images(data, dest_folder):
    for index, row in data.iterrows():
        image_name = row['Image_name'] + ".jpg"  
        source_path = os.path.join(image_folder, image_name)
        dest_path = os.path.join(dest_folder, image_name)
        copyfile(source_path, dest_path)
        
def copy_images_with_augmentation(data, dest_folder):
    for index, row in data.iterrows():
        image_name = row['Image_name'] + ".jpg"
        source_path = os.path.join(image_folder, image_name)
        dest_path = os.path.join(dest_folder, image_name)
        
        image = cv2.imread(source_path)  # Read image
        augmented_image = augment_image(image)  # Data augmentation
        
        cv2.imwrite(dest_path, augmented_image)  # Save augmented image
        
        # Also copy the original image to the training folder
        original_dest_path = os.path.join(dest_folder, "original_" + image_name)
        copyfile(source_path, original_dest_path)  # Copy original image

copy_images_with_augmentation(train_data, train_folder)
copy_images(val_data, val_folder)
copy_images(test_data, test_folder)

# %% [markdown]
# rt batch1

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from shutil import copyfile
import cv2
import numpy as np

csv_file = 'label/batch1label.csv'
data = pd.read_csv(csv_file)

image_folder = 'dataset_white/batch1'

train_folder = 'dataset_white/batch1_train'
val_folder = 'dataset_white/batch1_val'
test_folder = 'dataset_white/batch1_test'
for folder in [train_folder, val_folder, test_folder]:
    os.makedirs(folder, exist_ok=True)

train_data, test_data = train_test_split(data, test_size=0.2, shuffle=True, stratify=data['Firmness'], random_state=42)
val_data, test_data = train_test_split(test_data, test_size=0.5, shuffle=True, stratify=test_data['Firmness'], random_state=42)

def augment_image(image):
    # Image translation
    tx = np.random.randint(-20, 20)  # Random translation distance
    ty = np.random.randint(-20, 20)
    M_translate = np.float32([[1, 0, tx], [0, 1, ty]])  # Translation matrix
    translated_image = cv2.warpAffine(image, M_translate, (image.shape[1], image.shape[0]))

    # Image rotation
    angle = np.random.randint(-30, 30)  # Random rotation angle
    center = (image.shape[1] // 2, image.shape[0] // 2)  # Rotation center
    M_rotate = cv2.getRotationMatrix2D(center, angle, 1.0)  # Rotation matrix
    rotated_image = cv2.warpAffine(translated_image, M_rotate, (image.shape[1], image.shape[0]))
    
    return rotated_image

def copy_images(data, dest_folder):
    for index, row in data.iterrows():
        image_name = row['Image_name'] + ".jpg"  
        source_path = os.path.join(image_folder, image_name)
        dest_path = os.path.join(dest_folder, image_name)
        copyfile(source_path, dest_path)
        
def copy_images_with_augmentation(data, dest_folder):
    for index, row in data.iterrows():
        image_name = row['Image_name'] + ".jpg"  
        source_path = os.path.join(image_folder, image_name)
        dest_path = os.path.join(dest_folder, image_name)
        
        image = cv2.imread(source_path)  # Read image
        augmented_image = augment_image(image)  # Data augmentation
        
        cv2.imwrite(dest_path, augmented_image)  # Save augmented image
        
        # Also copy the original image to the training folder
        original_dest_path = os.path.join(dest_folder, "original_" + image_name)
        copyfile(source_path, original_dest_path)  # Copy original image

copy_images_with_augmentation(train_data, train_folder)
copy_images(val_data, val_folder)
copy_images(test_data, test_folder)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 59
#      56         original_dest_path = os.path.join(dest_folder, "original_" + image_name)
#      57         copyfile(source_path, original_dest_path)  # Copy original image
# ---> 59 copy_images_with_augmentation(train_data, train_folder)
#      60 copy_images(val_data, val_folder)
#      61 copy_images(test_data, test_folder)
#
# Cell In[1], line 51, in copy_images_with_augmentation(data, dest_folder)
#      48 dest_path = os.path.join(dest_folder, image_name)
#      50 image = cv2.imread(source_path)  # Read image
# ---> 51 augmented_image = augment_image(image)  # Data augmentation
#      53 cv2.imwrite(dest_path, augmented_image)  # Save augmented image
#      55 # Also copy the original image to the training folder
#
# Cell In[1], line 27, in augment_image(image)
#      25 ty = np.random.randint(-20, 20)
#      26 M_translate = np.float32([[1, 0, tx], [0, 1, ty]])  # Translation matrix
# ---> 27 translated_image = cv2.warpAffine(image, M_translate, (image.shape[1], image.shape[0]))
#      29 # Image rotation
#      30 angle = np.random.randint(-30, 30)  # Random rotation angle
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# 4cbatch1

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from shutil import copyfile
import cv2
import numpy as np

csv_file = '4cbatch1label.csv'
data = pd.read_csv(csv_file)

image_folder = '4cbatch1'

train_folder = '4cbatch1_train'
val_folder = '4cbatch1_val'
test_folder = '4cbatch1_test'
for folder in [train_folder, val_folder, test_folder]:
    os.makedirs(folder, exist_ok=True)

train_data, test_data = train_test_split(data, test_size=0.2, shuffle=True, stratify=data['Firmness'], random_state=42)
val_data, test_data = train_test_split(test_data, test_size=0.5, shuffle=True, stratify=test_data['Firmness'], random_state=42)

def augment_image(image):
    # Image translation
    tx = np.random.randint(-20, 20)  # Random translation distance
    ty = np.random.randint(-20, 20)
    M_translate = np.float32([[1, 0, tx], [0, 1, ty]])  # Translation matrix
    translated_image = cv2.warpAffine(image, M_translate, (image.shape[1], image.shape[0]))

    # Image rotation
    angle = np.random.randint(-30, 30)  # Random rotation angle
    center = (image.shape[1] // 2, image.shape[0] // 2)  # Rotation center
    M_rotate = cv2.getRotationMatrix2D(center, angle, 1.0)  # Rotation matrix
    rotated_image = cv2.warpAffine(translated_image, M_rotate, (image.shape[1], image.shape[0]))
    
    return rotated_image

def copy_images(data, dest_folder):
    for index, row in data.iterrows():
        image_name = row['Image_name'] + ".jpg"  
        source_path = os.path.join(image_folder, image_name)
        dest_path = os.path.join(dest_folder, image_name)
        copyfile(source_path, dest_path)
        
def copy_images_with_augmentation(data, dest_folder):
    for index, row in data.iterrows():
        image_name = row['Image_name'] + ".jpg"  
        source_path = os.path.join(image_folder, image_name)
        dest_path = os.path.join(dest_folder, image_name)
        
        image = cv2.imread(source_path)  # Read image
        augmented_image = augment_image(image)  # Data augmentation
        
        cv2.imwrite(dest_path, augmented_image)  # Save augmented image
        
        # Also copy the original image to the training folder
        original_dest_path = os.path.join(dest_folder, "original_" + image_name)
        copyfile(source_path, original_dest_path)  # Copy original image

copy_images_with_augmentation(train_data, train_folder)
copy_images(val_data, val_folder)
copy_images(test_data, test_folder)

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from shutil import copyfile
import cv2
import numpy as np

csv_file = 'batch1+2label.csv'
data = pd.read_csv(csv_file)

image_folder = 'batch1+2'

train_folder = 'batch1+2_train'
val_folder = 'batch1+2_val'
test_folder = 'batch1+2_test'
for folder in [train_folder, val_folder, test_folder]:
    os.makedirs(folder, exist_ok=True)

train_data, test_data = train_test_split(data, test_size=0.2, shuffle=True, stratify=data['Firmness'], random_state=42)
val_data, test_data = train_test_split(test_data, test_size=0.5, shuffle=True, stratify=test_data['Firmness'], random_state=42)

def augment_image(image):
    # Image translation
    tx = np.random.randint(-20, 20)  # Random translation distance
    ty = np.random.randint(-20, 20)
    M_translate = np.float32([[1, 0, tx], [0, 1, ty]])  # Translation matrix
    translated_image = cv2.warpAffine(image, M_translate, (image.shape[1], image.shape[0]))

    # Image rotation
    angle = np.random.randint(-30, 30)  # Random rotation angle
    center = (image.shape[1] // 2, image.shape[0] // 2)  # Rotation center
    M_rotate = cv2.getRotationMatrix2D(center, angle, 1.0)  # Rotation matrix
    rotated_image = cv2.warpAffine(translated_image, M_rotate, (image.shape[1], image.shape[0]))
    
    return rotated_image

def copy_images(data, dest_folder):
    for index, row in data.iterrows():
        image_name = row['Image_name'] + ".jpg"  
        source_path = os.path.join(image_folder, image_name)
        dest_path = os.path.join(dest_folder, image_name)
        copyfile(source_path, dest_path)
        
def copy_images_with_augmentation(data, dest_folder):
    for index, row in data.iterrows():
        image_name = row['Image_name'] + ".jpg"  
        source_path = os.path.join(image_folder, image_name)
        dest_path = os.path.join(dest_folder, image_name)
        
        image = cv2.imread(source_path)  # Read image
        augmented_image = augment_image(image)  # Data augmentation
        
        cv2.imwrite(dest_path, augmented_image)  # Save augmented image
        
        # Also copy the original image to the training folder
        original_dest_path = os.path.join(dest_folder, "original_" + image_name)
        copyfile(source_path, original_dest_path)  # Copy original image

copy_images_with_augmentation(train_data, train_folder)
copy_images(val_data, val_folder)
copy_images(test_data, test_folder)
